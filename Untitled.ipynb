# %%
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
import math

# %%
# Pandas dataframe read from csv file
df = pd.read_csv('globalterrorismdb_0616dist.csv', sep=',', low_memory=False)
print(df.shape)
# Out:
# (156772, 137)

# %%
#print(df.columns.values)

#df.head(20)

df.groupby('country_txt').count() #.sort_values( 'country_txt', ascending=False)
# Out:
#                           eventid  iyear  imonth  iday  approxdate  extended  \
# country_txt
# Afghanistan                  9690   9690    9690  9690         591      9690
# Albania                        77     77      77    77           0        77
# Algeria                      2720   2720    2720  2720          76      2720
# Andorra                         1      1       1     1           0         1
# Angola                        491    491     491   491           2       491
# Antigua and Barbuda             1      1       1     1           0         1
# Argentina                     804    804     804   804           0       804
# Armenia                        22     22      22    22           0        22
# Australia                      88     88      88    88           0        88
# Austria                       106    106     106   106           1       106
# Azerbaijan                     45     45      45    45           1        45
# ...
